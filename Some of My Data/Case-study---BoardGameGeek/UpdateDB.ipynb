# %%
games_data = []  # Assicurati che la lista sia inizializzata

import time
import requests
import xml.etree.ElementTree as ET

# %%
games_data = []  # Assicurati che la lista sia inizializzata

def get_data_with_backoff(game_id, max_retries=5):
    url = f"https://boardgamegeek.com/xmlapi2/thing?id={game_id}&stats=1"
    delay = 2  # Ritardo iniziale in secondi
    for i in range(max_retries):
        try:
            response = requests.get(url)
            response.raise_for_status()
            time.sleep(1)  # Pausa per evitare di sovraccaricare l'API

            # Parsing XML
            root = ET.fromstring(response.content)
            item = root.find("item")
            
            # Verifica presenza di dati
            if item is not None:
                # Usa il metodo `find` in modo sicuro con un controllo per ogni elemento
                year_published = item.find("yearpublished")
                year_published = int(year_published.get("value", 0)) if year_published is not None else None
                
                # Filtra solo i giochi dal 2022 in poi
                if year_published and year_published >= 2022:
                    game_info = {
                        "BGGId": game_id,
                        "Name": item.find("name").get("value") if item.find("name") is not None else "N/A",
                        "YearPublished": year_published,
                        "GameWeight": float(item.find("statistics/ratings/averageweight").get("value", 0)) if item.find("statistics/ratings/averageweight") is not None else 0,
                        "AvgRating": float(item.find("statistics/ratings/average").get("value", 0)) if item.find("statistics/ratings/average") is not None else 0,
                        "BayesAvgRating": float(item.find("statistics/ratings/bayesaverage").get("value", 0)) if item.find("statistics/ratings/bayesaverage") is not None else 0,
                        "NumOwned": int(item.find("statistics/ratings/owned").get("value", 0)) if item.find("statistics/ratings/owned") is not None else 0,
                        "NumComments": int(item.find("statistics/ratings/numcomments").get("value", 0)) if item.find("statistics/ratings/numcomments") is not None else 0,
                        "NumUserRatings": int(item.find("statistics/ratings/usersrated").get("value", 0)) if item.find("statistics/ratings/usersrated") is not None else 0,
                        "MinPlayers": int(item.find("minplayers").get("value", 1)) if item.find("minplayers") is not None else 1,
                        "MaxPlayers": int(item.find("maxplayers").get("value", 1)) if item.find("maxplayers") is not None else 1,
                        "MinPlaytime": int(item.find("minplaytime").get("value", 0)) if item.find("minplaytime") is not None else 0,
                        "MaxPlaytime": int(item.find("maxplaytime").get("value", 0)) if item.find("maxplaytime") is not None else 0,
                        "AgeRec": int(item.find("minage").get("value", 0)) if item.find("minage") is not None else 0,
                        "Description": item.find("description").text.strip() if item.find("description") is not None else ""
                    }
                    games_data.append(game_info)
                    print(f"Recuperati dati per il gioco {game_id}")
                    return game_info  # Esce dalla funzione se il recupero ha successo

        except requests.exceptions.HTTPError as e:
            if response.status_code == 429:
                print(f"Errore 429: Tentativo {i + 1} - Attendo {delay} secondi prima di riprovare...")
                time.sleep(delay)
                delay *= 2  # Raddoppia il ritardo
            else:
                print(f"Errore nel recuperare i dati per il gioco {game_id}: {e}")
                break
        except Exception as e:
            print(f"Errore generico per il gioco {game_id}: {e}")
            break

    return None  # Ritorna None se non riesce dopo max_retries tentativi

# %%
# Esegui per ogni ID di gioco
game_ids = range(359037,400000)  # La lista di ID di giochi che vuoi recuperare
for game_id in game_ids:
    get_data_with_backoff(game_id)
# Out:
# Recuperati dati per il gioco 359037
# Recuperati dati per il gioco 359040
# Recuperati dati per il gioco 359041
# Recuperati dati per il gioco 359042
# Recuperati dati per il gioco 359043
# Recuperati dati per il gioco 359044
# Recuperati dati per il gioco 359046
# Recuperati dati per il gioco 359048
# Recuperati dati per il gioco 359049
# Recuperati dati per il gioco 359050
# Recuperati dati per il gioco 359051
# Recuperati dati per il gioco 359052
# Recuperati dati per il gioco 359053
# Recuperati dati per il gioco 359055
# Recuperati dati per il gioco 359056
# Recuperati dati per il gioco 359062
# Recuperati dati per il gioco 359065
# Recuperati dati per il gioco 359066
# Recuperati dati per il gioco 359069
# Recuperati dati per il gioco 359073
# Recuperati dati per il gioco 359074
# Recuperati dati per il gioco 359078
# Recuperati dati per il gioco 359080
# Recuperati dati per il gioco 359082
# Recuperati dati per il gioco 359087
# Recuperati dati per il gioco 359088
# Recuperati dati per il gioco 359089
# Recuperati dati per il gioco 359090
# Recuperati dati per il gioco 359091
# Recuperati dati per il gioco 359092
# Recuperati dati per il gioco 359093
# Recuperati dati per il gioco 359095
# Recuperati dati per il gioco 359097
# Recuperati dati per il gioco 359098
# Recuperati dati per il gioco 359099
# Recuperati dati per il gioco 359102
# Recuperati dati per il gioco 359107
# Recuperati dati per il gioco 359108
# Recuperati dati per il gioco 359109
# Recuperati dati per il gioco 359113
# Recuperati dati per il gioco 359115
# Recuperati dati per il gioco 359117
# Recuperati dati per il gioco 359118
# Recuperati dati per il gioco 359119
# Recuperati dati per il gioco 359121
# Recuperati dati per il gioco 359122
# Recuperati dati per il gioco 359123
# Recuperati dati per il gioco 359124
# Recuperati dati per il gioco 359125
# Recuperati dati per il gioco 359126
# Recuperati dati per il gioco 359127
# Recuperati dati per il gioco 359128
# Recuperati dati per il gioco 359129
# Recuperati dati per il gioco 359130
# Recuperati dati per il gioco 359131
# Recuperati dati per il gioco 359132
# Recuperati dati per il gioco 359133
# Recuperati dati per il gioco 359135
# Recuperati dati per il gioco 359137
# Recuperati dati per il gioco 359138
# Recuperati dati per il gioco 359140
# Recuperati dati per il gioco 359141
# Recuperati dati per il gioco 359142
# Recuperati dati per il gioco 359145
# Recuperati dati per il gioco 359149
# Recuperati dati per il gioco 359152
# Recuperati dati per il gioco 359156
# Recuperati dati per il gioco 359157
# Recuperati dati per il gioco 359165
# Recuperati dati per il gioco 359170
# Recuperati dati per il gioco 359171
# Recuperati dati per il gioco 359172
# Recuperati dati per il gioco 359173
# Recuperati dati per il gioco 359175
# Recuperati dati per il gioco 359176
# Recuperati dati per il gioco 359177
# Recuperati dati per il gioco 359178
# Recuperati dati per il gioco 359179
# Recuperati dati per il gioco 359181
# Recuperati dati per il gioco 359183
# Recuperati dati per il gioco 359184
# Recuperati dati per il gioco 359185
# Recuperati dati per il gioco 359186
# Recuperati dati per il gioco 359189
# Recuperati dati per il gioco 359193
# Recuperati dati per il gioco 359195
# Recuperati dati per il gioco 359196
# Recuperati dati per il gioco 359197
# Recuperati dati per il gioco 359200
# Recuperati dati per il gioco 359205
# Recuperati dati per il gioco 359206
# Recuperati dati per il gioco 359207
# Recuperati dati per il gioco 359209
# Recuperati dati per il gioco 359210
# Recuperati dati per il gioco 359211
# Recuperati dati per il gioco 359212
# Recuperati dati per il gioco 359214
# Recuperati dati per il gioco 359215
# Recuperati dati per il gioco 359216
# Recuperati dati per il gioco 359217
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359218
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359219
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359220
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359221
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359222
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 359228
# Recuperati dati per il gioco 359231
# Recuperati dati per il gioco 359232
# Recuperati dati per il gioco 359234
# Recuperati dati per il gioco 359235
# Recuperati dati per il gioco 359237
# Recuperati dati per il gioco 359238
# Recuperati dati per il gioco 359239
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359240
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359241
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359242
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359247
# Recuperati dati per il gioco 359248
# Recuperati dati per il gioco 359249
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359250
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359251
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 359253
# Recuperati dati per il gioco 359254
# Recuperati dati per il gioco 359255
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359256
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359257
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359259
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359260
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359261
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 359271
# Recuperati dati per il gioco 359272
# Recuperati dati per il gioco 359273
# Recuperati dati per il gioco 359274
# Recuperati dati per il gioco 359275
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359276
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 359282
# Recuperati dati per il gioco 359283
# Recuperati dati per il gioco 359284
# Recuperati dati per il gioco 359285
# Recuperati dati per il gioco 359286
# Recuperati dati per il gioco 359288
# Recuperati dati per il gioco 359293
# Recuperati dati per il gioco 359294
# Recuperati dati per il gioco 359298
# Recuperati dati per il gioco 359299
# Recuperati dati per il gioco 359300
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 359302
# Recuperati dati per il gioco 359303
# Recuperati dati per il gioco 359304
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359305
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359311
# Recuperati dati per il gioco 359312
# Recuperati dati per il gioco 359313
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359314
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359315
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359317
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359318
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359319
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 359322
# Recuperati dati per il gioco 359324
# Recuperati dati per il gioco 359325
# Recuperati dati per il gioco 359328
# Recuperati dati per il gioco 359330
# Recuperati dati per il gioco 359334
# Recuperati dati per il gioco 359336
# Recuperati dati per il gioco 359337
# Recuperati dati per il gioco 359338
# Recuperati dati per il gioco 359346
# Recuperati dati per il gioco 359347
# Recuperati dati per il gioco 359348
# Recuperati dati per il gioco 359358
# Recuperati dati per il gioco 359361
# Recuperati dati per il gioco 359365
# Recuperati dati per il gioco 359366
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359368
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359371
# Recuperati dati per il gioco 359381
# Recuperati dati per il gioco 359382
# Recuperati dati per il gioco 359388
# Recuperati dati per il gioco 359394
# Recuperati dati per il gioco 359395
# Recuperati dati per il gioco 359397
# Recuperati dati per il gioco 359398
# Recuperati dati per il gioco 359399
# Recuperati dati per il gioco 359402
# Recuperati dati per il gioco 359404
# Recuperati dati per il gioco 359405
# Recuperati dati per il gioco 359406
# Recuperati dati per il gioco 359409
# Recuperati dati per il gioco 359411
# Recuperati dati per il gioco 359416
# Recuperati dati per il gioco 359417
# Recuperati dati per il gioco 359418
# Recuperati dati per il gioco 359420
# Recuperati dati per il gioco 359421
# Recuperati dati per il gioco 359422
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359423
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359427
# Recuperati dati per il gioco 359428
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359438
# Recuperati dati per il gioco 359442
# Recuperati dati per il gioco 359443
# Recuperati dati per il gioco 359445
# Recuperati dati per il gioco 359447
# Recuperati dati per il gioco 359450
# Recuperati dati per il gioco 359451
# Recuperati dati per il gioco 359452
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359454
# Recuperati dati per il gioco 359455
# Recuperati dati per il gioco 359456
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359457
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359458
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359459
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359460
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359461
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359462
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359463
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359464
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359465
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359466
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359467
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359468
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 359471
# Recuperati dati per il gioco 359472
# Recuperati dati per il gioco 359473
# Recuperati dati per il gioco 359475
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359476
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359477
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359478
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359479
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359480
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359481
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359483
# Recuperati dati per il gioco 359484
# Recuperati dati per il gioco 359485
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359486
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359487
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359488
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359489
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359490
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359491
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359492
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359493
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359494
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359495
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359496
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 359498
# Recuperati dati per il gioco 359499
# Recuperati dati per il gioco 359500
# Recuperati dati per il gioco 359501
# Recuperati dati per il gioco 359502
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 359504
# Recuperati dati per il gioco 359505
# Recuperati dati per il gioco 359510
# Recuperati dati per il gioco 359515
# Recuperati dati per il gioco 359516
# Recuperati dati per il gioco 359517
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359518
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359520
# Recuperati dati per il gioco 359521
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359523
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359524
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359527
# Recuperati dati per il gioco 359528
# Recuperati dati per il gioco 359531
# Recuperati dati per il gioco 359536
# Recuperati dati per il gioco 359537
# Recuperati dati per il gioco 359538
# Recuperati dati per il gioco 359539
# Recuperati dati per il gioco 359540
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359541
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359542
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359543
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359544
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359545
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359546
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359547
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359548
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359549
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359550
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359551
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359552
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 359554
# Recuperati dati per il gioco 359559
# Recuperati dati per il gioco 359560
# Recuperati dati per il gioco 359561
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359562
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359563
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359564
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359565
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359566
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359567
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359568
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359571
# Recuperati dati per il gioco 359574
# Recuperati dati per il gioco 359575
# Recuperati dati per il gioco 359577
# Recuperati dati per il gioco 359578
# Recuperati dati per il gioco 359580
# Recuperati dati per il gioco 359585
# Recuperati dati per il gioco 359586
# Recuperati dati per il gioco 359587
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359589
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359590
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 359597
# Recuperati dati per il gioco 359600
# Recuperati dati per il gioco 359601
# Recuperati dati per il gioco 359604
# Recuperati dati per il gioco 359611
# Recuperati dati per il gioco 359612
# Recuperati dati per il gioco 359613
# Recuperati dati per il gioco 359614
# Recuperati dati per il gioco 359617
# Recuperati dati per il gioco 359618
# Recuperati dati per il gioco 359619
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359620
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359621
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359622
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 359633
# Recuperati dati per il gioco 359635
# Recuperati dati per il gioco 359637
# Recuperati dati per il gioco 359639
# Recuperati dati per il gioco 359641
# Recuperati dati per il gioco 359642
# Recuperati dati per il gioco 359644
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 359646
# Recuperati dati per il gioco 359647
# Recuperati dati per il gioco 359652
# Recuperati dati per il gioco 359655
# Recuperati dati per il gioco 359657
# Recuperati dati per il gioco 359658
# Recuperati dati per il gioco 359659
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359660
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359661
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359662
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359663
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359664
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359667
# Recuperati dati per il gioco 359676
# Recuperati dati per il gioco 359677
# Recuperati dati per il gioco 359678
# Recuperati dati per il gioco 359679
# Recuperati dati per il gioco 359680
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359681
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359682
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359683
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 359685
# Recuperati dati per il gioco 359689
# Recuperati dati per il gioco 359690
# Recuperati dati per il gioco 359695
# Recuperati dati per il gioco 359696
# Recuperati dati per il gioco 359697
# Recuperati dati per il gioco 359698
# Recuperati dati per il gioco 359699
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359700
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359701
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359702
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359703
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359704
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359705
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359706
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359707
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359708
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359709
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359710
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359711
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359712
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359713
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359714
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359715
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359716
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359717
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359718
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359719
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359720
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359721
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 359723
# Recuperati dati per il gioco 359726
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359731
# Recuperati dati per il gioco 359744
# Recuperati dati per il gioco 359746
# Recuperati dati per il gioco 359747
# Recuperati dati per il gioco 359748
# Recuperati dati per il gioco 359750
# Recuperati dati per il gioco 359754
# Recuperati dati per il gioco 359755
# Recuperati dati per il gioco 359756
# Recuperati dati per il gioco 359758
# Recuperati dati per il gioco 359763
# Recuperati dati per il gioco 359764
# Recuperati dati per il gioco 359765
# Recuperati dati per il gioco 359766
# Recuperati dati per il gioco 359767
# Recuperati dati per il gioco 359768
# Recuperati dati per il gioco 359769
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 359773
# Recuperati dati per il gioco 359774
# Recuperati dati per il gioco 359775
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359776
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359777
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359784
# Recuperati dati per il gioco 359792
# Recuperati dati per il gioco 359799
# Recuperati dati per il gioco 359801
# Recuperati dati per il gioco 359803
# Recuperati dati per il gioco 359807
# Recuperati dati per il gioco 359809
# Recuperati dati per il gioco 359818
# Recuperati dati per il gioco 359822
# Recuperati dati per il gioco 359823
# Recuperati dati per il gioco 359824
# Recuperati dati per il gioco 359826
# Recuperati dati per il gioco 359827
# Recuperati dati per il gioco 359828
# Recuperati dati per il gioco 359829
# Recuperati dati per il gioco 359830
# Recuperati dati per il gioco 359831
# Recuperati dati per il gioco 359832
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359834
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359835
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359836
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359837
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359838
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359839
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359840
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359843
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359844
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359845
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359847
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 359848
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...

# %%
# Stampa i dati raccolti o esegui altre operazioni
print(f"Totale giochi recuperati: {len(games_data)}")

# %%
import pandas as pd
# Creazione del DataFrame
games_df = pd.DataFrame(games_data)

# Salva i dati in un file CSV
games_df.to_csv("games_2022daggioa_to_present.csv", index=False)
print("Dati salvati in games_2022daggioa_to_present.csv")
# Out:
# Dati salvati in games_2022_to_present.csv
