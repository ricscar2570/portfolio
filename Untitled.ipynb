# %%
games_data = []  # Assicurati che la lista sia inizializzata

import time
import requests
import xml.etree.ElementTree as ET

# %%
games_data = []  # Assicurati che la lista sia inizializzata

def get_data_with_backoff(game_id, max_retries=5):
    url = f"https://boardgamegeek.com/xmlapi2/thing?id={game_id}&stats=1"
    delay = 2  # Ritardo iniziale in secondi
    for i in range(max_retries):
        try:
            response = requests.get(url)
            response.raise_for_status()
            time.sleep(1)  # Pausa per evitare di sovraccaricare l'API

            # Parsing XML
            root = ET.fromstring(response.content)
            item = root.find("item")
            
            # Verifica presenza di dati
            if item is not None:
                # Usa il metodo `find` in modo sicuro con un controllo per ogni elemento
                year_published = item.find("yearpublished")
                year_published = int(year_published.get("value", 0)) if year_published is not None else None
                
                # Filtra solo i giochi dal 2022 in poi
                if year_published and year_published >= 2022:
                    game_info = {
                        "BGGId": game_id,
                        "Name": item.find("name").get("value") if item.find("name") is not None else "N/A",
                        "YearPublished": year_published,
                        "GameWeight": float(item.find("statistics/ratings/averageweight").get("value", 0)) if item.find("statistics/ratings/averageweight") is not None else 0,
                        "AvgRating": float(item.find("statistics/ratings/average").get("value", 0)) if item.find("statistics/ratings/average") is not None else 0,
                        "BayesAvgRating": float(item.find("statistics/ratings/bayesaverage").get("value", 0)) if item.find("statistics/ratings/bayesaverage") is not None else 0,
                        "NumOwned": int(item.find("statistics/ratings/owned").get("value", 0)) if item.find("statistics/ratings/owned") is not None else 0,
                        "NumComments": int(item.find("statistics/ratings/numcomments").get("value", 0)) if item.find("statistics/ratings/numcomments") is not None else 0,
                        "NumUserRatings": int(item.find("statistics/ratings/usersrated").get("value", 0)) if item.find("statistics/ratings/usersrated") is not None else 0,
                        "MinPlayers": int(item.find("minplayers").get("value", 1)) if item.find("minplayers") is not None else 1,
                        "MaxPlayers": int(item.find("maxplayers").get("value", 1)) if item.find("maxplayers") is not None else 1,
                        "MinPlaytime": int(item.find("minplaytime").get("value", 0)) if item.find("minplaytime") is not None else 0,
                        "MaxPlaytime": int(item.find("maxplaytime").get("value", 0)) if item.find("maxplaytime") is not None else 0,
                        "AgeRec": int(item.find("minage").get("value", 0)) if item.find("minage") is not None else 0,
                        "Description": item.find("description").text.strip() if item.find("description") is not None else ""
                    }
                    games_data.append(game_info)
                    print(f"Recuperati dati per il gioco {game_id}")
                    return game_info  # Esce dalla funzione se il recupero ha successo

        except requests.exceptions.HTTPError as e:
            if response.status_code == 429:
                print(f"Errore 429: Tentativo {i + 1} - Attendo {delay} secondi prima di riprovare...")
                time.sleep(delay)
                delay *= 2  # Raddoppia il ritardo
            else:
                print(f"Errore nel recuperare i dati per il gioco {game_id}: {e}")
                break
        except Exception as e:
            print(f"Errore generico per il gioco {game_id}: {e}")
            break

    return None  # Ritorna None se non riesce dopo max_retries tentativi

# %%
# Esegui per ogni ID di gioco
game_ids = range(349161,350000)  # La lista di ID di giochi che vuoi recuperare
for game_id in game_ids:
    get_data_with_backoff(game_id)

# Stampa i dati raccolti o esegui altre operazioni
print(f"Totale giochi recuperati: {len(games_data)}")
# Out:
# Recuperati dati per il gioco 349161
# Recuperati dati per il gioco 349179
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 349183
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 349187
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 349201
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 349222
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349224
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349225
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 349227
# Recuperati dati per il gioco 349228
# Errore 429: Tentativo 3 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349242
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349256
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349267
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349268
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349269
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349275
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 349285
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349286
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 5 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349315
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349329
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349344
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 349363
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349369
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 349373
# Errore 429: Tentativo 5 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 349387
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349394
# Recuperati dati per il gioco 349396
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 349409
# Errore 429: Tentativo 4 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349416
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349434
# Recuperati dati per il gioco 349440
# Recuperati dati per il gioco 349442
# Recuperati dati per il gioco 349444
# Recuperati dati per il gioco 349448
# Recuperati dati per il gioco 349449
# Recuperati dati per il gioco 349451
# Recuperati dati per il gioco 349463
# Recuperati dati per il gioco 349464
# Recuperati dati per il gioco 349468
# Recuperati dati per il gioco 349470
# Recuperati dati per il gioco 349473
# Recuperati dati per il gioco 349474
# Recuperati dati per il gioco 349493
# Recuperati dati per il gioco 349501
# Recuperati dati per il gioco 349502
# Recuperati dati per il gioco 349503
# Recuperati dati per il gioco 349504
# Recuperati dati per il gioco 349505
# Recuperati dati per il gioco 349507
# Recuperati dati per il gioco 349508
# Recuperati dati per il gioco 349509
# Recuperati dati per il gioco 349510
# Recuperati dati per il gioco 349511
# Recuperati dati per il gioco 349512
# Recuperati dati per il gioco 349513
# Recuperati dati per il gioco 349514
# Recuperati dati per il gioco 349515
# Recuperati dati per il gioco 349516
# Recuperati dati per il gioco 349517
# Recuperati dati per il gioco 349518
# Recuperati dati per il gioco 349519
# Recuperati dati per il gioco 349523
# Recuperati dati per il gioco 349568
# Recuperati dati per il gioco 349575
# Recuperati dati per il gioco 349578
# Recuperati dati per il gioco 349579
# Recuperati dati per il gioco 349580
# Recuperati dati per il gioco 349581
# Recuperati dati per il gioco 349582
# Recuperati dati per il gioco 349586
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 349606
# Recuperati dati per il gioco 349607
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349629
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 5 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 349675
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 349701
# Recuperati dati per il gioco 349703
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 5 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349707
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349725
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 349739
# Recuperati dati per il gioco 349740
# Recuperati dati per il gioco 349741
# Recuperati dati per il gioco 349742
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349743
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349744
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349745
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 349747
# Recuperati dati per il gioco 349748
# Recuperati dati per il gioco 349750
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349751
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 349753
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349767
# Recuperati dati per il gioco 349769
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 349773
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349779
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349792
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349793
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 349810
# Recuperati dati per il gioco 349814
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349815
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349816
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349817
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 349819
# Recuperati dati per il gioco 349820
# Recuperati dati per il gioco 349821
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349822
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349823
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349824
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349825
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349827
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349835
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 349847
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349852
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 5 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349885
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349906
# Recuperati dati per il gioco 349907
# Recuperati dati per il gioco 349908
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349909
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349916
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349918
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349919
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 349928
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349943
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 349947
# Recuperati dati per il gioco 349948
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 349963
# Recuperati dati per il gioco 349967
# Recuperati dati per il gioco 349968
# Recuperati dati per il gioco 349969
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Recuperati dati per il gioco 349975
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 4 - Attendo 4 secondi prima di riprovare...
# Recuperati dati per il gioco 349991
# Errore 429: Tentativo 1 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 3 - Attendo 4 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Errore 429: Tentativo 2 - Attendo 2 secondi prima di riprovare...
# Totale giochi recuperati: 130

# %%
import pandas as pd
# Creazione del DataFrame
games_df = pd.DataFrame(games_data)

# Salva i dati in un file CSV
games_df.to_csv("games_2022_to_present.csv", index=False)
print("Dati salvati in games_2022_to_present.csv")
# Out:
# Dati salvati in games_2022_to_present.csv
